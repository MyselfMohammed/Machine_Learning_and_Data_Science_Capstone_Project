# %%
# from File - Univariate import Class - Univariate
from Univariate import Univariate

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Preprocessed_Data_Cryptos.csv")
dataset.head()
# Out:
#    Year  Month  Day  Hour  Minute  Volume  Open  High   Low  Close  \
# 0  2012      1    1    10       1     0.0  4.58  4.58  4.58   4.58
# 1  2012      1    1    10       2     0.0  4.58  4.58  4.58   4.58
# 2  2012      1    1    10       3     0.0  4.58  4.58  4.58   4.58
# 3  2012      1    1    10       4     0.0  4.58  4.58  4.58   4.58
# 4  2012      1    1    10       5     0.0  4.58  4.58  4.58   4.58
#
#   Price_Prediction
# 0          Neutral
# 1          Neutral
# 2          Neutral
# 3          Neutral
# 4          Neutral

# %%
quan,qual=Univariate.quanQual(dataset)

# %%
quan
# Out:
# ['Year',
#  'Month',
#  'Day',
#  'Hour',
#  'Minute',
#  'Volume',
#  'Open',
#  'High',
#  'Low',
#  'Close']

# %%
qual
# Out:
# ['Price_Prediction']
